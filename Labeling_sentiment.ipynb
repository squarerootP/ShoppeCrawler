# %%
# Load model directly
from transformers import AutoTokenizer, AutoModelForSequenceClassification

tokenizer = AutoTokenizer.from_pretrained("wonrax/phobert-base-vietnamese-sentiment")
model = AutoModelForSequenceClassification.from_pretrained("wonrax/phobert-base-vietnamese-sentiment")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/285 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/895k [00:00<?, ?B/s]
# bpe.codes:   0%|          | 0.00/1.14M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/17.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/150 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/999 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/540M [00:00<?, ?B/s]

# %%
import pandas as pd

# %%
df = pd.DataFrame(pd.read_csv('/content/reviews_khoa.csv'))
df.head()
# Out:
#                                              comment  label
# 0  đúng với mô tả:lều xông tự bung chất lượng sản...    NaN
# 1                                vài mỏng lều nhỏ tí    NaN
# 2                      sp lỗi shop giai quyết như qq    NaN
# 3                                           lều mỏng    NaN
# 4                                 mỏng quá mỏng luôn    NaN

# %%
X = df['comment']

# %%
# prompt: use the imported model to predict the output using X

import torch

def predict_sentiment(text):
  inputs = tokenizer(text, padding=True, truncation=True, return_tensors='pt')
  outputs = model(**inputs)
  predicted_class = torch.argmax(outputs.logits, dim=1).item()
  return predicted_class

# Assuming X contains the text you want to predict
predictions = []
for text in X:
  try:
    predictions.append(predict_sentiment(text))
  except Exception as e:
    print(f"Error processing text: {text}, Error: {e}")
    predictions.append(-1) # Or handle the error differently

# predictions

# %%
len(predictions)
# Out:
# 568

# %%
df['label'] = predictions

# %%
df.head()
# Out:
#                                              comment  label
# 0  đúng với mô tả:lều xông tự bung chất lượng sản...      0
# 1                                vài mỏng lều nhỏ tí      2
# 2                      sp lỗi shop giai quyết như qq      1
# 3                                           lều mỏng      2
# 4                                 mỏng quá mỏng luôn      0

# %%
df['label'] = df['label'].apply(lambda x: 'positive' if x == 1 else 'negative' if x == 0 else 'neutral')

# %%
df.head()
# Out:
#                                              comment     label
# 0  đúng với mô tả:lều xông tự bung chất lượng sản...  negative
# 1                                vài mỏng lều nhỏ tí   neutral
# 2                      sp lỗi shop giai quyết như qq  positive
# 3                                           lều mỏng   neutral
# 4                                 mỏng quá mỏng luôn  negative

# %%
df.to_csv('final_Khoa.csv')

# %%
df1 = pd.DataFrame(pd.read_csv('/content/final_Khoa.csv'))
df2 = pd.DataFrame(pd.read_csv('/content/final_Phuong.csv'))
df3 = pd.DataFrame(pd.read_csv('/content/final_Quynh.csv'))
df4 = pd.DataFrame(pd.read_csv('/content/final.csv'))

# %%
# prompt: concat 4 dfs above

import pandas as pd
df_final = pd.concat([df1, df2, df3, df4], ignore_index=True)
# Out:
# (7785, 3)

# %%
df_final.columns
df_final = df_final.drop('Unnamed: 0', axis=1)

# %%
df_final.head()
# Out:
#                                              comment     label
# 0  đúng với mô tả:lều xông tự bung chất lượng sản...  negative
# 1                                vài mỏng lều nhỏ tí   neutral
# 2                      sp lỗi shop giai quyết như qq  positive
# 3                                           lều mỏng   neutral
# 4                                 mỏng quá mỏng luôn  negative

# %%
df_final.to_csv('concatted_finals.csv')
